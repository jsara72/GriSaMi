# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
# author: jsara72
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords
import random
import nltk
from nltk.corpus import movie_reviews
import pandas as pd
import re
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB,BernoulliNB
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC

# %%
class tweet_analysis:
    
    def sort_info(file):

        idt = []
        text = []
        location = []
        geo = []
        coordinates = []
        created_at = []
        retweet_count = []
        retweeted = []
        lang = []
        user_mentions = []
        hashtags = []
        symbols = []
        count = []
        n0 = 0

        with open(file, 'r') as f:
            lines = f.readlines()
            for line in lines:
                tweet = json.loads(line)
                if len(tweet) == 1:
                    continue
                else:
                    if tweet['lang'] != 'en':
                        continue
                    else:
                        idt.append(tweet['id'])
                        text.append(tweet['text'])
                        location.append(tweet['user']['location'])
                        #geo.append(tweet['geo'])
                        #coordinates.append(tweet['coordinates'])
                        created_at.append(tweet['created_at'])
                        retweeted.append(tweet['retweeted'])
                        retweet_count.append(tweet['retweet_count'])
                        lang.append(tweet['lang'])
                        mentions = tweet['entities']['user_mentions']
                        hashno = tweet['entities']['hashtags']
                        symb = tweet['entities']['symbols']
                        if len(mentions)==0 or len(hashno)==0 or len(symb)==0:
                            user_mentions.append('None')
                            hashtags.append('None')
                            symbols.append('None')
                        else:
                            user_mentions.append(mentions)
                            hashtags.append(hashno)
                            symbols.append(symb)
                
                        n0 += 1
                        count.append(n0)
                    

        df1 = pd.DataFrame({'id': idt,
                        'location': location},
                           index=count)
        df2 = pd.DataFrame({'language': lang,
                        'text': text,
                        'symbols':symbols,
                        'hashtags':hashtags},
                        index=count)
        df3 = pd.DataFrame({'user_mentions': user_mentions,
                        'retweeted': retweeted,
                        'retweet_count': retweet_count},
                        index=count)
        df4 = pd.concat([df1, df2, df3], axis=1)
        
        return(df4)

# %%
df = tweet_analysis.sort_info('00.json')

# %%
df
# Out:
#                       id                        location hashtags language  \
# 1     748742932174237697                           Yemen     None       en
# 2     748742932182601728     *Parody Account to Inspire*     None       en
# 3     748742932178440194                         Canada      None       en
# 4     748742932170022913                       fairfield     None       en
# 5     748742932207800320                  Turkey/Denizli     None       en
# 6     748742932186800128    Eranhipalam, Calicut, Kerala     None       en
# 7     748742932178407425            wishing i was asleep     None       en
# 8     748742932174295040                      minovio241     None       en
# 9     748742932203577344             Mumbai, Maharashtra     None       en
# 10    748742932174213124                   Baltimore, MD     None       en
# 11    748742932182671361                         Arizona     None       en
# 12    748742932199460864                            829❥     None       en
# 13    748742932182671360                            None     None       en
# 14    748742932207837184               Granite Falls, WA     None       en
# 15    748742936376987648                            None     None       en
# 16    748742936381140992                Calgary, Alberta     None       en
# 17    748742936368558080                   Godric Hollow     None       en
# 18    748742936402141184                 Los Angeles, CA     None       en
# 19    748742936368525314         [#1 Fan/Parody Account]     None       en
# 20    748742936376975360                   San Diego Ca,     None       en
# 21    748742936364322818     *Parody Account to Inspire*     None       en
# 22    748742936372781056              kpop + khh + anime     None       en
# 23    748742936372793344                     Philippines     None       en
# 24    748742936385376258                      Boston, MA     None       en
# 25    748742936372736001        via G.Poli 33/35 Portici     None       en
# 26    748742936402153472                North Plains ,OR     None       en
# 27    748742936376946688              Booval, Queensland     None       en
# 28    748742940583800832                            None     None       en
# 29    748742940596461571                            None     None       en
# 30    748742940583866368                    South Africa     None       en
# ...                  ...                             ...      ...      ...
# 995   748743171262124032                            None     None       en
# 996   748743171249623041                            None     None       en
# 997   748743175473238017                        Barbados     None       en
# 998   748743175477424129                            None     None       en
# 999   748743175469051904                            None     None       en
# 1000  748743175469043713        Australia  (not Austria)     None       en
# 1001  748743175443845120           Saint-Martine, Québec     None       en
# 1002  748743175473229824                          Panamá     None       en
# 1003  748743175477473280                            None     None       en
# 1004  748743175443914753                South Wales, UK.     None       en
# 1005  748743175464857600                          Mumbai     None       en
# 1006  748743175452319746                           Waco      None       en
# 1007  748743175460655104               São Paulo, Brasil     None       en
# 1008  748743175443845121                     Dorchester      None       en
# 1009  748743179638235136                            None     None       en
# 1010  748743179659161601                            None     None       en
# 1011  748743179638181888                    Harlem World     None       en
# 1012  748743179634036741                            None     None       en
# 1013  748743179650736128                            None     None       en
# 1014  748743179633987584                     S.C. U.S.A.     None       en
# 1015  748743179633995776                     Chicago, IL     None       en
# 1016  748743179633979397                 New Jersey, USA     None       en
# 1017  748743179671711744                     Atlanta, GA     None       en
# 1018  748743179659202561            เชียงใหม่, ประเทศไทย     None       en
# 1019  748743179633987586  Fitzgerald-229 ✈Statesboro-912     None       en
# 1020  748743179654926336         Sydney, New South Wales     None       en
# 1021  748743179642351618                            None     None       en
# 1022  748743179650801665                         houston     None       en
# 1023  748743179671785472                            None     None       en
# 1024  748743179650756612                  Washington, DC     None       en
#
#      symbols                                               text  \
# 1       None             Need 1-2 for wagers with @idfwUntitleD
# 2       None  I still remember how we started talking, I tru...
# 3       None                             @HarborGuava hi khaled
# 4       None  HAPPY BIRTHDAY TO MY GIRLS @swandaughter_ AND ...
# 5       None  RT @5SOSVoteStats: Sometimes I feel like I'm g...
# 6       None  Good doctors know how to prescribe the most im...
# 7       None  RT @thinkbri: how to: friendship by me https:/...
# 8       None  RT @neymarjr: Nice work @Ronaldo but I’ll just...
# 9       None  Follow @theofficialsbi &amp; Join #StateBankDa...
# 10      None  It Be Small Confusing The 1st week 🙄😩 https://...
# 11      None  RT @Arizona_DPS: Distracted Driving killed 3,1...
# 12      None  @chaaante_ I really never knew what she meant ...
# 13      None  RT @CuteOverloads: Belly rubs 💕 https://t.co/Y...
# 14      None  RT @ItsFoodPorn: Cinnamon Roll Bread https://t...
# 15      None  And in increase of Christe's lawe dear,\nThey ...
# 16      None  Why is branding such a powerful tool? Because ...
# 17      None   Convinced I'm Just Not The Type Guys Wanna Date.
# 18      None                  @Christian_Gonzo in the NFL, sure
# 15                0     False          None
# 16                0     False          None
# 17                0     False          None
# 18                0     False          None
# 19                0     False          None
# 20                0     False          None
# 21                0     False          None
# 22                0     False          None
# 23                0     False          None
# 24                0     False          None
# 25                0     False          None
# 26                0     False          None
# 27                0     False          None
# 28                0     False          None
# 29                0     False          None
# 30                0     False          None
# ...             ...       ...           ...
# 995               0     False          None
# 996               0     False          None
# 997               0     False          None
# 998               0     False          None
# 999               0     False          None
# 1000              0     False          None
# 1001              0     False          None
# 1002              0     False          None
# 1003              0     False          None
# 1004              0     False          None
# 1005              0     False          None
# 1006              0     False          None
# 1007              0     False          None
# 1008              0     False          None
# 1009              0     False          None
# 1010              0     False          None
# 1011              0     False          None
# 1012              0     False          None
# 1013              0     False          None
# 1014              0     False          None
# 1015              0     False          None
# 1016              0     False          None
# 1017              0     False          None
# 1018              0     False          None
# 1019              0     False          None
# 1020              0     False          None
# 1021              0     False          None
# 1022              0     False          None
# 1023              0     False          None
# 1024              0     False          None
#
# [1024 rows x 9 columns]

# %%
df['location']

# %%
def find_features(document, word_features):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)
    
    return features


def text_classifier():
    documents = [(list(movie_reviews.words(fileid)), category)
                 for category in movie_reviews.categories()
                 for fileid in movie_reviews.fileids(category)]

    random.shuffle(documents)

    all_words = []
    for w in movie_reviews.words():
        all_words.append(w.lower())
    all_words = nltk.FreqDist(all_words)
    word_features = list(all_words.keys())[:3000]


    featuresets = [(find_features(rev, word_features), category) for (rev, category) in documents]


    training_set = featuresets[:1900]
    testing_set = featuresets[1900:]

#    SVC_classifier = SklearnClassifier(SVC())
#    SVC_classifier.train(training_set)
#    print("SVC_classifier accuracy percent:", (nltk.classify.accuracy(SVC_classifier, testing_set))*100)
#    MNB_classifier = SklearnClassifier(MultinomialNB())
#    MNB_classifier.train(training_set)
#    print("MultinomialNB accuracy percent:",nltk.classify.accuracy(MNB_classifier, testing_set))

    BNB_classifier = SklearnClassifier(BernoulliNB())
    BNB_classifier.train(training_set)
    print("BernoulliNB accuracy percent:",nltk.classify.accuracy(BNB_classifier, testing_set))
    text_classifier.classifier = BNB_classifier


def get_verb_tags():
    return ["VB", "VBD", "VBG", "VBN", "VBP", "VBZ"]


def list_pos_tagger(all_sentences):
    for sentence in all_sentences:
        pos_tagger(sentence)


def pos_tagger(text):

    tokens = word_tokenize(text)

    stop_words = set(stopwords.words('english'))
    filtered_tokens = [w for w in tokens if not w in stop_words]
    print("most common words: ", nltk.FreqDist(filtered_tokens).most_common(20)) 
    print(text, text_classifier.classifier.classify(find_features(text, filtered_tokens)))

    tagged = pos_tag(tokens)
#    print "tagged: ", tagged

    verbs = [w[0] for w in tagged if w[1] in get_verb_tags()]
#    print "verbs: ", verbs


def sentence_tokenize(text):
    return nltk.sent_tokenize(text)

def get_tweet_text():
    # TODO: is buggy!
    f = open("Archive/results/filtered_tweets/part-00000") # 36726-7 tweets in this file
#    reg = re.compile("\w+:[[\[.+\]]|[^,]*]*[,\n]")
#    keys = "[\bid\b | \bcreated_at\b | \btext\b | \blang\b | \bsource\b | \buser\b | \bentities\b | \bretweeted\b | \bretweet_count\b | \n]"
#    keys = "[id:|created_at:|text:|lang:|source:|user:|entities:|retweeted:|retweet_count:|\n]"
#    reg = re.compile(keys+"[^"+keys+"]*")
#    get_tweet_text.structured_tweets = map(lambda x: x[0:-1].split(':',1), reg.findall(f.read()))
    reg = re.compile("text:.*lang:")
    get_tweet_text.structured_tweets = map(lambda x: re.sub(r'[^\x00-\x7F]+',' ', x[5:-6]), reg.findall(f.read()))
#    print len(get_tweet_text.structured_tweets)
    return get_tweet_text.structured_tweets


#sentence = """At eight o'clock on Thursday morning Arthur didn't feel very good. He was going to university."""
#f = open("Archive/results/filtered_tweets/part-00000")
text_classifier()
all_sentences = []
for tweet in get_tweet_text()[0:5]:
    all_sentences.append(tweet)
list_pos_tagger(all_sentences)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/nltk/corpus/util.py in __load(self)
#      62             except LookupError as e:
# ---> 63                 try: root = nltk.data.find('corpora/%s' % zip_name)
#      64                 except LookupError: raise e
#
# //anaconda/lib/python3.5/site-packages/nltk/data.py in find(resource_name, paths)
#     640     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 641     raise LookupError(resource_not_found)
#     642
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/movie_reviews.zip/movie_reviews/' not found.
#   Please use the NLTK Downloader to obtain the resource:  >>>
#   nltk.download()
#   Searched in:
#     - '/Users/miguelsilva/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-3-e75b1c46c9ed> in <module>()
#      88 #sentence = """At eight o'clock on Thursday morning Arthur didn't feel very good. He was going to university."""
#      89 #f = open("Archive/results/filtered_tweets/part-00000")
# ---> 90 text_classifier()
#      91 all_sentences = []
#      92 for tweet in get_tweet_text()[0:5]:
#
# <ipython-input-3-e75b1c46c9ed> in text_classifier()
#      13 def text_classifier():
#      14     documents = [(list(movie_reviews.words(fileid)), category)
# ---> 15                  for category in movie_reviews.categories()
#      16                  for fileid in movie_reviews.fileids(category)]
#      17
#
# //anaconda/lib/python3.5/site-packages/nltk/corpus/util.py in __getattr__(self, attr)
#      97             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#      98
# ---> 99         self.__load()
#     100         # This looks circular, but its not, since __load() changes our
#     101         # __class__ to something new:
#
# //anaconda/lib/python3.5/site-packages/nltk/corpus/util.py in __load(self)
#      62             except LookupError as e:
#      63                 try: root = nltk.data.find('corpora/%s' % zip_name)
# ---> 64                 except LookupError: raise e
#      65
#      66         # Load the corpus.
#
# //anaconda/lib/python3.5/site-packages/nltk/corpus/util.py in __load(self)
#      59         else:
#      60             try:
# ---> 61                 root = nltk.data.find('corpora/%s' % self.__name)
#      62             except LookupError as e:
#      63                 try: root = nltk.data.find('corpora/%s' % zip_name)
#
# //anaconda/lib/python3.5/site-packages/nltk/data.py in find(resource_name, paths)
#     639     sep = '*' * 70
#     640     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 641     raise LookupError(resource_not_found)
#     642
#     643
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/movie_reviews' not found.  Please use the NLTK
#   Downloader to obtain the resource:  >>> nltk.download()
#   Searched in:
#     - '/Users/miguelsilva/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
